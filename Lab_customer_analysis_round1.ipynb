# %%
import pandas as pd

# %%
df1 = pd.read_csv(r'~/Desktop/Bootcamp/Week-1/lab-customer-analysis-round-1/files_for_lab/csv_files/file1.csv')

# %%
df1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
df1.tail()
# Out:
#      Customer   ST GENDER Education Customer Lifetime Value  Income  \
# 4003      NaN  NaN    NaN       NaN                     NaN     NaN
# 4004      NaN  NaN    NaN       NaN                     NaN     NaN
# 4005      NaN  NaN    NaN       NaN                     NaN     NaN
# 4006      NaN  NaN    NaN       NaN                     NaN     NaN
# 4007      NaN  NaN    NaN       NaN                     NaN     NaN
#
#       Monthly Premium Auto Number of Open Complaints Policy Type  \
# 4003                   NaN                       NaN         NaN
# 4004                   NaN                       NaN         NaN
# 4005                   NaN                       NaN         NaN
# 4006                   NaN                       NaN         NaN
# 4007                   NaN                       NaN         NaN
#
#      Vehicle Class  Total Claim Amount
# 4003           NaN                 NaN
# 4004           NaN                 NaN
# 4005           NaN                 NaN
# ...

# %%
df2 = pd.read_csv(r'~/Desktop/Bootcamp/Week-1/lab-customer-analysis-round-1/files_for_lab/csv_files/file2.csv')

# %%
df3 = pd.read_csv(r'~/Desktop/Bootcamp/Week-1/lab-customer-analysis-round-1/files_for_lab/csv_files/file3.csv')

# %%
print(df1.shape, df2.shape, df3.shape)
# Out:
# (4008, 11) (996, 11) (7070, 11)

# %%
df1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
df2.head(2)
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
#
#      Policy Type  Vehicle Class
# 0  Personal Auto  Four-Door Car
# 1   Special Auto            SUV

# %%
df3.head(2)
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
#
#    Total Claim Amount Vehicle Class
# 0          499.200000  Two-Door Car
# 1            3.468912  Two-Door Car

# %%
df1.columns.str.capitalize()
# Out:
# Index(['Customer', 'St', 'Gender', 'Education', 'Customer lifetime value',
#        'Income', 'Monthly premium auto', 'Number of open complaints',
#        'Policy type', 'Vehicle class', 'Total claim amount'],
#       dtype='object')

# %%
df1.columns = df1.columns.str.capitalize()
df1
# Out:
#      Customer          St Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer lifetime value   Income  Monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df1.columns = df1.columns.str.replace("St", "State")
df1
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer lifetime value   Income  Monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2.columns = df2.columns.str.capitalize()
df2.columns = df2.columns.str.replace("St", "State")
df2.head(2)
# Out:
#   Customer       State Gender Education Customer lifetime value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
#
#    Monthly premium auto Number of open complaints  Total claim amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
#
#      Policy type  Vehicle class
# 0  Personal Auto  Four-Door Car
# 1   Special Auto            SUV

# %%
df3.columns = df3.columns.str.capitalize()
df3.head(1)
# Out:
#   Customer       State  Customer lifetime value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
#
#    Income  Monthly premium auto  Number of open complaints    Policy type  \
# 0       0                   104                          0  Personal Auto
#
#    Total claim amount Vehicle class
# 0               499.2  Two-Door Car

# %%
df1.columns.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[197], line 1
# ----> 1 df1.columns.sort()
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5780, in Index.sort(self, *args, **kwargs)
#    5775 @final
#    5776 def sort(self, *args, **kwargs):
#    5777     """
#    5778     Use sort_values instead.
#    5779     """
# -> 5780     raise TypeError("cannot sort an Index object in-place, use sort_values instead")
#
# TypeError: cannot sort an Index object in-place, use sort_values instead

# %%
df1.columns.sort_values()
# Out:
# Index(['Customer', 'Customer lifetime value', 'Education', 'Gender', 'Income',
#        'Monthly premium auto', 'Number of open complaints', 'Policy type',
#        'State', 'Total claim amount', 'Vehicle class'],
#       dtype='object')

# %%
df1_sorted = df1.reindex(sorted(df1.columns), axis=1)
df1_sorted
# Out:
#      Customer Customer lifetime value             Education Gender   Income  \
# 0     RB50392                     NaN                Master    NaN      0.0
# 1     QZ44356              697953.59%              Bachelor      F      0.0
# 2     AI49188             1288743.17%              Bachelor      F  48767.0
# 3     WW63253              764586.18%              Bachelor      M      0.0
# 4     GA49547              536307.65%  High School or Below      M  36357.0
# ...       ...                     ...                   ...    ...      ...
# 4003      NaN                     NaN                   NaN    NaN      NaN
# 4004      NaN                     NaN                   NaN    NaN      NaN
# 4005      NaN                     NaN                   NaN    NaN      NaN
# 4006      NaN                     NaN                   NaN    NaN      NaN
# 4007      NaN                     NaN                   NaN    NaN      NaN
#
# ...

# %%
df2_sorted = df2.reindex(sorted(df2.columns), axis=1)
df2_sorted
# Out:
#     Customer Customer lifetime value Education Gender  Income  \
# 0    GS98873              323912.47%  Bachelor      F   16061
# 1    CW49887              462680.11%    Master      F   79487
# 2    MY31220              899704.02%   College      F   54230
# 3    UH35128             2580706.30%   College      F   71210
# 4    WH52799              380812.21%   College      F   94903
# ..       ...                     ...       ...    ...     ...
# 991  HV85198              847141.75%    Master      M   63513
# 992  BS91566              543121.91%   College      F   58161
# 993  IL40123              568964.41%   College      F   83640
# 994  MY32149              368672.38%    Master      F       0
# 995  SA91515              399258.39%  Bachelor      M       0
#
#      Monthly premium auto Number of open complaints     Policy type  \
# 0                      88                    1/0/00   Personal Auto
# 1                     114                    1/0/00    Special Auto
# ...

# %%
df3_sorted = df3.reindex(sorted(df3.columns), axis=1)
df3_sorted
# Out:
#      Customer  Customer lifetime value             Education Gender  Income  \
# 0     SA25987              3479.137523  High School or Below      M       0
# 1     TB86706              2502.637401                Master      M       0
# 2     ZL73902              3265.156348              Bachelor      F   25820
# 3     KX23516              4455.843406  High School or Below      F       0
# 4     FN77294              7704.958480  High School or Below      M   30366
# ...       ...                      ...                   ...    ...     ...
# 7065  LA72316             23405.987980              Bachelor      M   71941
# 7066  PK87824              3096.511217               College      F   21604
# 7067  TD14365              8163.890428              Bachelor      M       0
# 7068  UP19263              7524.442436               College      M   21941
# 7069  Y167826              2611.836866               College      M       0
#
# ...

# %%
list=[df1_sorted, df2_sorted, df3_sorted]

# %%
df_result = pd.concat(list)

# %%
df_result
# Out:
#      Customer Customer lifetime value             Education Gender   Income  \
# 0     RB50392                     NaN                Master    NaN      0.0
# 1     QZ44356              697953.59%              Bachelor      F      0.0
# 2     AI49188             1288743.17%              Bachelor      F  48767.0
# 3     WW63253              764586.18%              Bachelor      M      0.0
# 4     GA49547              536307.65%  High School or Below      M  36357.0
# ...       ...                     ...                   ...    ...      ...
# 7065  LA72316             23405.98798              Bachelor      M  71941.0
# 7066  PK87824             3096.511217               College      F  21604.0
# 7067  TD14365             8163.890428              Bachelor      M      0.0
# 7068  UP19263             7524.442436               College      M  21941.0
# 7069  Y167826             2611.836866               College      M      0.0
#
# ...

# %%
#Which columns are numerical
df_result.dtypes
# Out:
# Customer                      object
# Customer lifetime value       object
# Education                     object
# Gender                        object
# Income                       float64
# Monthly premium auto         float64
# Number of open complaints     object
# Policy type                   object
# State                         object
# Total claim amount           float64
# Vehicle class                 object
# dtype: object

# %%
#Which columns are categorical
numerical_col = ['Customer', 'St', 'Gender', 'Education', 'Policy type', 'vehicle class', 'State']
numerical_col
# Out:
# ['Customer',
#  'St',
#  'Gender',
#  'Education',
#  'Policy type',
#  'vehicle class',
#  'State']

# %%
df_result.head()
# Out:
#   Customer Customer lifetime value             Education Gender   Income  \
# 0  RB50392                     NaN                Master    NaN      0.0
# 1  QZ44356              697953.59%              Bachelor      F      0.0
# 2  AI49188             1288743.17%              Bachelor      F  48767.0
# 3  WW63253              764586.18%              Bachelor      M      0.0
# 4  GA49547              536307.65%  High School or Below      M  36357.0
#
#    Monthly premium auto Number of open complaints     Policy type       State  \
# 0                1000.0                    1/0/00   Personal Auto  Washington
# 1                  94.0                    1/0/00   Personal Auto     Arizona
# 2                 108.0                    1/0/00   Personal Auto      Nevada
# 3                 106.0                    1/0/00  Corporate Auto  California
# 4                  68.0                    1/0/00   Personal Auto  Washington
#
#    Total claim amount  Vehicle class
# ...

# %%
df_result.columns
# Out:
# Index(['Customer', 'Customer lifetime value', 'Education', 'Gender', 'Income',
#        'Monthly premium auto', 'Number of open complaints', 'Policy type',
#        'State', 'Total claim amount', 'Vehicle class'],
#       dtype='object')

# %%
df_drop_col = df_result.drop(['Education', 'Number of open complaints'], axis=1)
df_drop_col
# Out:
#      Customer Customer lifetime value Gender   Income  Monthly premium auto  \
# 0     RB50392                     NaN    NaN      0.0                1000.0
# 1     QZ44356              697953.59%      F      0.0                  94.0
# 2     AI49188             1288743.17%      F  48767.0                 108.0
# 3     WW63253              764586.18%      M      0.0                 106.0
# 4     GA49547              536307.65%      M  36357.0                  68.0
# ...       ...                     ...    ...      ...                   ...
# 7065  LA72316             23405.98798      M  71941.0                  73.0
# 7066  PK87824             3096.511217      F  21604.0                  79.0
# 7067  TD14365             8163.890428      M      0.0                  85.0
# 7068  UP19263             7524.442436      M  21941.0                  96.0
# 7069  Y167826             2611.836866      M      0.0                  77.0
#
# ...

# %%
df_drop_col.columns = df_drop_col.columns.str.replace(" ", "_")
df_drop_col.head(2)
# Out:
#   Customer Customer_lifetime_value Gender  Income  Monthly_premium_auto  \
# 0  RB50392                     NaN    NaN     0.0                1000.0
# 1  QZ44356              697953.59%      F     0.0                  94.0
#
#      Policy_type       State  Total_claim_amount  Vehicle_class
# 0  Personal Auto  Washington            2.704934  Four-Door Car
# 1  Personal Auto     Arizona         1131.464935  Four-Door Car

# %%
df_drop_col['Customer_lifetime_value'] = df_drop_col.Customer_lifetime_value.str.replace('%', ' ')
df_drop_col
# Out:
#      Customer Customer_lifetime_value Gender   Income  Monthly_premium_auto  \
# 0     RB50392                     NaN    NaN      0.0                1000.0
# 1     QZ44356              697953.59       F      0.0                  94.0
# 2     AI49188             1288743.17       F  48767.0                 108.0
# 3     WW63253              764586.18       M      0.0                 106.0
# 4     GA49547              536307.65       M  36357.0                  68.0
# ...       ...                     ...    ...      ...                   ...
# 7065  LA72316                     NaN      M  71941.0                  73.0
# 7066  PK87824                     NaN      F  21604.0                  79.0
# 7067  TD14365                     NaN      M      0.0                  85.0
# 7068  UP19263                     NaN      M  21941.0                  96.0
# 7069  Y167826                     NaN      M      0.0                  77.0
#
# ...

# %%
df_drop_col['Customer_lifetime_value']  = df_drop_col.Customer_lifetime_value.astype('float')
df_drop_col
# Out:
#      Customer  Customer_lifetime_value Gender   Income  Monthly_premium_auto  \
# 0     RB50392                      NaN    NaN      0.0                1000.0
# 1     QZ44356                697953.59      F      0.0                  94.0
# 2     AI49188               1288743.17      F  48767.0                 108.0
# 3     WW63253                764586.18      M      0.0                 106.0
# 4     GA49547                536307.65      M  36357.0                  68.0
# ...       ...                      ...    ...      ...                   ...
# 7065  LA72316                      NaN      M  71941.0                  73.0
# 7066  PK87824                      NaN      F  21604.0                  79.0
# 7067  TD14365                      NaN      M      0.0                  85.0
# 7068  UP19263                      NaN      M  21941.0                  96.0
# 7069  Y167826                      NaN      M      0.0                  77.0
#
# ...

# %%
df_drop_col['Customer_lifetime_value'] = df_drop_col.Customer_lifetime_value/100
df_drop_col
# Out:
#      Customer  Customer_lifetime_value Gender   Income  Monthly_premium_auto  \
# 0     RB50392                      NaN    NaN      0.0                1000.0
# 1     QZ44356                69.795359      F      0.0                  94.0
# 2     AI49188               128.874317      F  48767.0                 108.0
# 3     WW63253                76.458618      M      0.0                 106.0
# 4     GA49547                53.630765      M  36357.0                  68.0
# ...       ...                      ...    ...      ...                   ...
# 7065  LA72316                      NaN      M  71941.0                  73.0
# 7066  PK87824                      NaN      F  21604.0                  79.0
# 7067  TD14365                      NaN      M      0.0                  85.0
# 7068  UP19263                      NaN      M  21941.0                  96.0
# 7069  Y167826                      NaN      M      0.0                  77.0
#
# ...

# %%
df_final = df_drop_col.drop_duplicates()
df_final
# Out:
#      Customer  Customer_lifetime_value Gender   Income  Monthly_premium_auto  \
# 0     RB50392                      NaN    NaN      0.0                1000.0
# 1     QZ44356                69.795359      F      0.0                  94.0
# 2     AI49188               128.874317      F  48767.0                 108.0
# 3     WW63253                76.458618      M      0.0                 106.0
# 4     GA49547                53.630765      M  36357.0                  68.0
# ...       ...                      ...    ...      ...                   ...
# 7065  LA72316                      NaN      M  71941.0                  73.0
# 7066  PK87824                      NaN      F  21604.0                  79.0
# 7067  TD14365                      NaN      M      0.0                  85.0
# 7068  UP19263                      NaN      M  21941.0                  96.0
# 7069  Y167826                      NaN      M      0.0                  77.0
#
# ...
